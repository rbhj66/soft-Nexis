# %%
import pandas as pd
data = pd.read_csv("sales.csv")
print(data.head())
# Out:
#          Date     Product     Category Region  Sales  Profit  Quantity
# 0  2026-01-01      Laptop  Electronics  North  55000   12000         5
# 1  2026-01-02      Mobile  Electronics  South  30000    8000        10
# 2  2026-01-03      Tablet  Electronics   East  20000    5000         6
# 3  2026-01-04  Headphones  Accessories   West   5000    1500        15
# 4  2026-01-05    Keyboard  Accessories  North   4000    1000        12

# %%
import numpy as np 
arr = np.array([10,20,30])
print(arr.mean())
# Out:
# 20.0

# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [10,20,30]
plt.plot(x,y)
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sales.csv")

# %%
print(data.head())
# Out:
#          Date     Product     Category Region  Sales  Profit  Quantity
# 0  2026-01-01      Laptop  Electronics  North  55000   12000         5
# 1  2026-01-02      Mobile  Electronics  South  30000    8000        10
# 2  2026-01-03      Tablet  Electronics   East  20000    5000         6
# 3  2026-01-04  Headphones  Accessories   West   5000    1500        15
# 4  2026-01-05    Keyboard  Accessories  North   4000    1000        12

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20 non-null     object
#  1   Product   20 non-null     object
#  2   Category  20 non-null     object
#  3   Region    20 non-null     object
#  4   Sales     20 non-null     int64
#  5   Profit    20 non-null     int64
#  6   Quantity  20 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 1.2+ KB
# None

# %%
print(data.isnull().sum())
# Out:
# Date        0
# Product     0
# Category    0
# Region      0
# Sales       0
# Profit      0
# Quantity    0
# dtype: int64

# %%
print(data["Sales"].sum())
# Out:
# 350900

# %%
print(data["Sales"].mean())
# Out:
# 17545.0

# %%
print(data.groupby("Product")
      ["Sales"].sum())
# Out:
# Product
# Headphones     10500
# Keyboard        8200
# Laptop        115000
# Mobile         62000
# Monitor        31000
# Mouse           7200
# Printer        24500
# Smartwatch     37000
# Speaker        14500
# Tablet         41000
# Name: Sales, dtype: int64

# %%
product_sales=data.groupby("Product")["Sales"].sum()

# %%
product_sales.plot(kind="pie", autopct='%1.1f%%')
plt.show()

# %%
data["Sales"].plot()
plt.show()
